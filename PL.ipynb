# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay2224/Akshay2224.github.io/blob/master/PL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="test"
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# a=1 print(type(a))

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('EPL_20_21.csv')

# %%
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
df.describe()
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.287594        717.750000              77.823872       0.191729
# std      2.095191        631.372522              13.011631       0.850881
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Club', 'Nationality', 'Position', 'Age', 'Matches', 'Starts',
#        'Mins', 'Goals', 'Assists', 'Passes_Attempted', 'Perc_Passes_Completed',
#        'Penalty_Goals', 'Penalty_Attempted', 'xG', 'xA', 'Yellow_Cards',
#        'Red_Cards'],
#       dtype='object')

# %%
df.sort_values('Goals', ascending=False)
# Out:
#                    Name                  Club Nationality Position  Age  \
# 162          Harry Kane     Tottenham Hotspur         ENG       FW   27
# 81        Mohamed Salah          Liverpool FC         EGY       FW   28
# 51      Bruno Fernandes     Manchester United         POR       MF   25
# 161       Son Heung-min     Tottenham Hotspur         KOR       FW   28
# 214     Patrick Bamford          Leeds United         ENG       FW   26
# ..                  ...                   ...         ...      ...  ...
# 481      Conor Townsend  West Bromwich Albion         ENG       DF   27
# 475       Sam Johnstone  West Bromwich Albion         ENG       GK   27
# 495    Filip Krovinović  West Bromwich Albion         CRO       MF   24
# 494    Robert Snodgrass  West Bromwich Albion         SCO    MF,FW   32
# 493  Branislav Ivanović  West Bromwich Albion         SRB       DF   36
#
#      Matches  Starts  Mins  Goals  Assists  Passes_Attempted  \
# ...

# %%
df[df.Goals>20]
# Out:
#               Name               Club Nationality Position  Age  Matches  \
# 81   Mohamed Salah       Liverpool FC         EGY       FW   28       37
# 162     Harry Kane  Tottenham Hotspur         ENG       FW   27       35
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 81       34  3078     22        5              1288                   83.2
# 162      35  3082     23       14               937                   70.1
#
#      Penalty_Goals  Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# 81               6                  6  0.61  0.18             0          0
# 162              4                  4  0.60  0.22             1          0

# %%
df['Goals'].fillna(0)
# Out:
# 0      6
# 1      0
# 2      6
# 3      3
# 4      1
#       ..
# 527    0
# 528    0
# 529    0
# 530    0
# 531    0
# Name: Goals, Length: 532, dtype: int64

# %%
df['Goals'].apply(np.sum)
# Out:
# 0      6
# 1      0
# 2      6
# 3      3
# 4      1
#       ..
# 527    0
# 528    0
# 529    0
# 530    0
# 531    0
# Name: Goals, Length: 532, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Name', 'Club', 'Nationality', 'Position', 'Age', 'Matches', 'Starts',
#        'Mins', 'Goals', 'Assists', 'Passes_Attempted', 'Perc_Passes_Completed',
#        'Penalty_Goals', 'Penalty_Attempted', 'xG', 'xA', 'Yellow_Cards',
#        'Red_Cards'],
#       dtype='object')

# %%
data = pd.DataFrame(df,columns=['Club', 'Goals'])
new_df=data.groupby('Club')['Goals'].sum()
new_df.plot.pie(y="Club")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.Club.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Club'>

# %%
df.columns
# Out:
# Index(['Name', 'Club', 'Nationality', 'Position', 'Age', 'Matches', 'Starts',
#        'Mins', 'Goals', 'Assists', 'Passes_Attempted', 'Perc_Passes_Completed',
#        'Penalty_Goals', 'Penalty_Attempted', 'xG', 'xA', 'Yellow_Cards',
#        'Red_Cards'],
#       dtype='object')

# %%
df = pd.read_csv('Premier_League.csv')
df.head()
# Out:
#             date   clock                  stadium attendance       Home Team  \
# 0  28th May 2023  4:30pm         Emirates Stadium     60,095         Arsenal
# 1  28th May 2023  4:30pm               Villa Park     42,212     Aston Villa
# 2  28th May 2023  4:30pm  Gtech Community Stadium     17,120       Brentford
# 3  28th May 2023  4:30pm          Stamford Bridge     40,130         Chelsea
# 4  28th May 2023  4:30pm            Selhurst Park     25,198  Crystal Palace
#
#    Goals Home                 Away Team  Away Goals  home_possessions  \
# 0           5   Wolverhampton Wanderers           0              51.0
# 1           2  Brighton and Hove Albion           1              40.3
# 2           1           Manchester City           0              34.4
# 3           1          Newcastle United           1              64.4
# 4           1         Nottingham Forest           1              66.0
#
#    away_possessions  ...  away_duels  home_saves  away_saves  home_fouls  \
# ...
